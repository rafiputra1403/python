# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiputra1403/python/blob/main/edge_segmetesion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import canny
from skimage import data,morphology
from skimage.color import rgb2gray
import scipy.ndimage as nd
import cv2 
import numpy as np
from google.colab.patches import cv2_imshow
plt.rcParams["figure.figsize"] = (12,8)
# %matplotlib inline

# %%
image1 = cv2.imread('sonic.png')

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000 at 0x7F3CD44C2E80>

# %%
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=2000x2000 at 0x7F3D0C38BDC0>

# %%
edges = canny(img)
plt.imshow(edges, interpolation='gaussian')
plt.title('Canny detector')
# Out:
# Text(0.5, 1.0, 'Canny detector')

# %%
fill_im = nd.binary_fill_holes(edges)
plt.imshow(fill_im)
plt.title('Region Filling')
# Out:
# Text(0.5, 1.0, 'Region Filling')

# %%
from skimage.filters import sobel
elevation_map = sobel(img)
fig, ax = plt.subplots(figsize=(4, 3))
ax.imshow(elevation_map, cmap=plt.cm.gray, interpolation='nearest')
ax.axis('on')
ax.set_title('elevation_map')
# Text(0.5, 1.0, 'elevation_map')
# Out:
# Text(0.5, 1.0, 'elevation_map')
