# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiputra1403/python/blob/main/uts_visi_komputer_muhammadrafiputraarianto_23419037.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
from google.colab.patches import cv2_imshow

# %%
image1 = cv2.imread('onic.png')

# %%
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh1 = cv2.threshold(img, 50, 730, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 50, 730, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 50, 730, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 50, 730, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 50, 730, cv2.THRESH_TOZERO_INV)

# %%
cv2_imshow(image1)
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F99189EA710>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F98F483BA00>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F98F483B670>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F98F483BA00>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F98F483B670>
# <PIL.Image.Image image mode=L size=225x225 at 0x7F98F483BA00>
